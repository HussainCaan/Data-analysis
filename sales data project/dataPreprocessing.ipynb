# %%
import pandas as pd

data = pd.read_excel('salesdata project excel.xlsx')

# %%
data = pd.DataFrame(data)
print(data.columns)
# Out:
# Index(['Date', 'Customer Name', 'State', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Profit'],
#       dtype='object')

# %%
data['Date'] = pd.to_datetime(data['Date'])
data.to_excel("cleaned sales data.xlsx")
# Out:
#            Date    Customer Name       State         Category Sub-Category  \
# 0    2014-01-02  Bradley Drucker   Wisconsin       Technology  Accessories
# 1    2014-01-03      Dave Brooks  Washington        Furniture       Chairs
# 2    2014-01-03   Hallie Redmond    New York       Technology       Phones
# 3    2014-01-03   Vicky Freymann    Illinois        Furniture       Chairs
# 4    2014-01-03   Vicky Freymann    Illinois  Office Supplies        Paper
# ...         ...              ...         ...              ...          ...
# 9989 2016-12-31  Brian DeCherney  California       Technology       Phones
# 9990 2016-12-31       Emily Phan     Florida  Office Supplies          Art
# 9991 2016-12-31       Emily Phan     Florida  Office Supplies        Paper
# 9992 2016-12-31        Becky Pak  California  Office Supplies      Binders
# 9993 2016-12-31     Duane Benoit        Ohio  Office Supplies      Storage
#
# ...
